# %% [markdown]
#    I want to filter my searches through various salaries. Build timed for loops for pluck job title, company, description, location. May also want to broaden my location range (currently set to within 25 miles of Chicago). After making a list of data for each salary range I need to concat all my lists into one data frame. Then I need to drop all dups. Add a column to show salary. Define high_salary and document, add as a column. Search through for common words, CountVectorizer (for the body of dataframe). Determine the words that appear most often (which ones of them correlate to high_salary?). Begin thinking about which models to use, run the models, pick best three and talk about them.

# %%
import urllib2
from bs4 import BeautifulSoup
import time
from time import sleep
import pandas as pd

# %%
soup = BeautifulSoup(urllib2.urlopen('http://www.indeed.com/jobs?q=data+scientist+%2455%2C000&l=Chicago%2C+IL&start=').read())

# %%
print soup.prettify()

# %%
for div in soup('div', {'class': 'row result'}):
    print div.prettify()
    print '\n\n'

# %%
#here I pulled all job titles from each listing from the first page
for i in soup('div', {'class': ' row result'}):
    for j in i('a', {'data-tn-element': 'jobTitle'}):
#         print j.prettify()
        print j.get_text()
        print '\n'

# %%
# here I pulled all company names from each listing from the first page
# I will then go down and combine this to make a for loop to gather all my info
for i in soup('div', {'class': ' row result'}):
    for j in i('span', {'class': 'company'}):
#         print j.prettify()
        print j.get_text()
        print '\n'

# %% [markdown]
# Beginning of My Work $55,000

# %%
soup55 = BeautifulSoup(urllib2.urlopen('http://www.indeed.com/jobs?q=data+scientist+$55,000&l=Chicago,+IL&start=').read())

# %%
web_page = 'http://www.indeed.com/jobs?q=data+scientist+$55,000&l=Chicago,+IL&start='

# %%
for i in range(0,101,10):
    web_page = 'http://www.indeed.com/jobs?q=data+scientist+$55,000&l=Chicago,+IL&start=' + str(i)
    sleep(5)
    print web_page
    print i
# http://www.indeed.com/jobs?q=data+scientist+%2455%2C000&l=Chicago%2C+IL&start=
# soup = BeautifulSoup(urllib2.urlopen('http://www.indeed.com/jobs?q=data+scientist+%2455%2C000&l=Chicago%2C+IL&start=').read())

# %%
#built a loop to filter all my identifiers from 1 page of postings within salary 55,000k
#I will want to go back up and run my timed loop for page requests then re-run this
#I will run this whole chunk again for each salary range results
#might want to also try this in multiple locations (Seattle, San Fran, DC,)
# salary_55k = [] 
# for i in soup55('div', {'class': ' row result'}):
#     for j in i('span', {'class': 'company'}):
#         print 'Comapany name is %s' % j.text 
#         salary_55k.append(j.text)
#     for j in i('span', {'class': 'location'}):
#         print 'Job is located in %s' % j.text
#         salary_55k.append(j.text)
#     for j in i('span', {'class': 'summary'}):
#         print 'Job summary is %s' % j.text
#         salary_55k.append(j.text)
        
# redo above code using this as template            
job_title = []
company_name = []
location = []
summary = []
for i in range(0,501,10):
    time.sleep(1)
    print 'starting loop', i
    web_page = 'http://www.indeed.com/jobs?q=data+scientist+$55,000&l=Chicago,+IL&start=' + str(i)
    print web_page
    soup55 = BeautifulSoup(urllib2.urlopen(web_page).read())
    for i in soup55('div', {'class': ' row result'}):
        for j in i('a', {'data-tn-element': 'jobTitle'}):
            print 'Job title is %s' % j.text
            job_title.append((j.text).encode('utf-8').strip())
        for j in i('span', {'class': 'company'}):
            print 'Comapany name is %s' % j.text 
            company_name.append((j.text).encode('utf-8').strip())
        for j in i('span', {'class': 'location'}):
            print 'Job is located in %s' % j.text
            location.append((j.text).encode('utf-8').strip())
        for j in i('span', {'class': 'summary'}):
            print 'Job summary is %s' % j.text
            summary.append((j.text).encode('utf-8').strip())
            
# added salary column here
salary_55k = {'Job Title' : job_title, 'Company Name' : company_name, 
               'Location' : location, 'Summary' : summary, 'Salary' : 55000,
              'High Salary' : 0}
salary_55k
# Out:
# starting loop 0
# http://www.indeed.com/jobs?q=data+scientist+$55,000&l=Chicago,+IL&start=0
# /Users/Driz/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# Job title is Data Scientist
# Comapany name is
#
#
#         The University of Chicago Medicine
#
# Job is located in Chicago, IL
# Job summary is
# The Data Scientist will also be responsible for data profiling/cleansing data governance consultation, data quality assessment, data mart mapping and data...
# Job title is Chief Data Scientist (equity position)
# ...

# %%
# added salary column here
salary_55k = {'Job Title' : job_title, 'Company Name' : company_name, 
               'Location' : location, 'Summary' : summary, 'Salary' : 55000,
              'High Salary' : 0}
salary_55k
# Out:
# {'Company Name': ['Digital Factory',
#   'Anomalix',
#   'GE Transportation',
#   'Google',
#   'Civis Analytics',
#   'Illinois Technology Association',
#   'Civis Analytics',
#   'BMW Technology Corporation',
#   'Wolverine Trading',
#   'IBM',
#   'Willis Towers Watson',
#   'VitalSource Staffing',
#   'Hirewell',
#   'Enterprise Consulting Services',
#   'Selby Jennings',
#   'University of Chicago, Center for Data Intensive S',
#   'Trunk Club',
#   'Workbridge Associates',
#   'Civis Analytics',
#   'NJF Search',
#   'Allstate Insurance',
#   'Analytic Recruiting',
#   'e.biT',
#   'Civis Analytics',
#   'Civis Analytics',
#   'Optiver',
#   'Civis Analytics',
#   'Johnson Controls',
#   'Deloitte',
#   'GinasTechJobs.com',
#   'Shoprunner',
#   'Hirewell',
#   'Workbridge Associates',
#   'Civis Analytics',
#   'Amazon Web Services, Inc.',
#   'Raise Marketplace Inc.',
#   'Metropolitan Water Reclamation District of Greater...',
#   'IBM Kenexa',
#   'Capgemini',
# ...

# %%
# turn dictionary of scraped info into a dataframe for each filtered salary results. 
# then will need to concat all salary df's together and save as csv file
df_55 = pd.DataFrame(salary_55k)

# %%
df_55.head()
# Out:
#         Company Name  High Salary  \
# 0    Digital Factory            0
# 1           Anomalix            0
# 2  GE Transportation            0
# 3             Google            0
# 4    Civis Analytics            0
#
#                                            Job Title     Location  Salary  \
# 0             Chief Data Scientist (equity position)  Chicago, IL   55000
# 1                                     Data Scientist  Chicago, IL   55000
# 2                              Senior Data Scientist  Chicago, IL   55000
# 3  Machine Learning Deployment Engineer, Professi...  Chicago, IL   55000
# 4                 Data Scientist - Unstructured Data  Chicago, IL   55000
#
#                                              Summary
# 0  Chief Data Scientist*. We are looking for an e...
# 1  Data Scientist Responsibilities will include:....
# 2  The Senior Data Scientist will demonstrate lea...
# 3  Experience interpreting technical data and cre...
# ...

# %%
#need to create a table. identify columns and rows
#Do I have enough entries from 55k? Do I want to collect more?
salary_55k

# %% [markdown]
# Moving on to $70,000 data collection

# %%
#try this to see if I get different job listings. Defines 70k
# internet was broken when I tried to run this
http://www.indeed.com/jobs?q=data+scientist+$70,000&l=Chicago,+IL&start=

# %%
# Tried to fix my repetative job listings by changing the soup= to my filtered salary page
# It doesnt seem to be working cause now my loop for soup2 wont run
soup70 = BeautifulSoup(urllib2.urlopen('http://www.indeed.com/jobs?q=data+scientist+$70,000&l=Chicago,+IL&start=').read())

# %%
urllib2.urlopen('http://www.indeed.com/jobs?q=data+scientist+$70,000&l=Chicago,+IL&start=').read()

# %%
# need to fix this
for i in range(0,101,10):
    web_page = 'http://www.indeed.com/jobs?q=data+scientist+$70,000&l=Chicago,+IL&start=' + str(i)
    sleep(5)
    print web_page
    print i

# %%
# Here I smooshed my loops together and now it is looping through pages
# and then looping through the body of each page to pull my job postings
# job_title = []
# company_name = []
# location = []
# summary = []
# for i in range(0,101,10):
#     time.sleep(1)
#     print 'starting loop ', i
#     web_page = 'http://www.indeed.com/jobs?q=data+scientist+$70,000&l=Chicago,+IL&start=' + str(i)
#     soup70 = BeautifulSoup(urllib2.urlopen(web_page).read())
#     for i in soup70('div', {'class': ' row result'}):
#         for j in i('a', {'data-tn-element': 'jobTitle'}):
#             print 'Job title is %s' % j.text
#             job_title.append((j.text).encode('utf-8'))
#         for j in i('span', {'class': 'company'}):
#             print 'Comapany name is %s' % j.text 
#             salary_70k.append(j.text)
#         for j in i('span', {'class': 'location'}):
#             print 'Job is located in %s' % j.text
#             salary_70k.append(j.text)
#         for j in i('span', {'class': 'summary'}):
#             print 'Job summary is %s' % j.text
#             salary_70k.append(j.text)
            
# redo above code using this as template            
job_title = []
company_name = []
location = []
summary = []
for i in range(0,501,10):
    time.sleep(1)
    print 'starting loop', i
    web_page = 'http://www.indeed.com/jobs?q=data+scientist+$70,000&l=Chicago,+IL&start=' + str(i)
    print web_page
    soup70 = BeautifulSoup(urllib2.urlopen(web_page).read())
    for i in soup70('div', {'class': ' row result'}):
        for j in i('a', {'data-tn-element': 'jobTitle'}):
            print 'Job title is %s' % j.text
            job_title.append((j.text).encode('utf-8').strip())
        for j in i('span', {'class': 'company'}):
            print 'Comapany name is %s' % j.text 
            company_name.append((j.text).encode('utf-8').strip())
        for j in i('span', {'class': 'location'}):
            print 'Job is located in %s' % j.text
            location.append((j.text).encode('utf-8').strip())
        for j in i('span', {'class': 'summary'}):
            print 'Job summary is %s' % j.text
            summary.append((j.text).encode('utf-8').strip())
# Out:
# starting loop 0
# http://www.indeed.com/jobs?q=data+scientist+$70,000&l=Chicago,+IL&start=0
# Job title is Data Scientist
# Comapany name is
#
#     Strike Social
#
# Job is located in Chicago, IL 60601 (Loop area)
# Job summary is
# Data Scientist at Strike Social. Our Data Scientists research and create our learning infrastructure using R and Python and then work with Data Engineering to...
# Job title is Data Scientist
# Comapany name is
#
#
#         The University of Chicago Medicine
#
# Job is located in Chicago, IL
# Job summary is
# The Data Scientist will also be responsible for data profiling/cleansing data governance consultation, data quality assessment, data mart mapping and data...
# Job title is AVP, Credit Innovation Data Scientist (L11)
# Comapany name is
#
#
#         Synchrony Financial
#
# Job is located in Chicago, IL
# Job summary is
# ...

# %%
# added salary column here
salary_70k = {'Job Title' : job_title, 'Company Name' : company_name, 
               'Location' : location, 'Summary' : summary, 'Salary' : 70000,
              'High Salary' : 0}
salary_70k
# Out:
# {'Company Name': ['Digital Factory',
#   'Anomalix',
#   'GE Transportation',
#   'Google',
#   'Civis Analytics',
#   'Illinois Technology Association',
#   'Civis Analytics',
#   'BMW Technology Corporation',
#   'Wolverine Trading',
#   'IBM',
#   'Willis Towers Watson',
#   'VitalSource Staffing',
#   'Hirewell',
#   'Enterprise Consulting Services',
#   'Selby Jennings',
#   'University of Chicago, Center for Data Intensive S',
#   'Trunk Club',
#   'Workbridge Associates',
#   'Civis Analytics',
#   'NJF Search',
#   'Allstate Insurance',
#   'Analytic Recruiting',
#   'e.biT',
#   'Civis Analytics',
#   'Civis Analytics',
#   'Optiver',
#   'Civis Analytics',
#   'Johnson Controls',
#   'Deloitte',
#   'GinasTechJobs.com',
#   'Shoprunner',
#   'Hirewell',
#   'Workbridge Associates',
#   'Civis Analytics',
#   'Amazon Web Services, Inc.',
#   'Raise Marketplace Inc.',
#   'Metropolitan Water Reclamation District of Greater...',
#   'IBM Kenexa',
#   'Capgemini',
# ...

# %%
df_70 = pd.DataFrame(salary_70k)
df_70.head()
# Out:
#         Company Name  High Salary  \
# 0    Digital Factory            0
# 1           Anomalix            0
# 2  GE Transportation            0
# 3             Google            0
# 4    Civis Analytics            0
#
#                                            Job Title     Location  Salary  \
# 0             Chief Data Scientist (equity position)  Chicago, IL   70000
# 1                                     Data Scientist  Chicago, IL   70000
# 2                              Senior Data Scientist  Chicago, IL   70000
# 3  Machine Learning Deployment Engineer, Professi...  Chicago, IL   70000
# 4                 Data Scientist - Unstructured Data  Chicago, IL   70000
#
#                                              Summary
# 0  Chief Data Scientist*. We are looking for an e...
# 1  Data Scientist Responsibilities will include:....
# 2  The Senior Data Scientist will demonstrate lea...
# 3  Experience interpreting technical data and cre...
# ...

# %% [markdown]
# Moving on to $80,000 data collection

# %%
for i in range(0,101,10):
    web_page = 'http://www.indeed.com/q-data-scientist-$85,000-l-Chicago,-IL-jobs.html' + str(i)
    sleep(5)
    print web_page
    print i

# %%
# salary_80k = [] 
# for i in range(0,101,10):
#     time.sleep(1)
#     print 'starting loop', i
#     web_page = 'http://www.indeed.com/jobs?q=data+scientist+$80,000&l=Chicago,+IL&start=' + str(i)
#     print web_page
#     soup80 = BeautifulSoup(urllib2.urlopen(web_page).read())
#     for i in soup80('div', {'class': ' row result'}):
#         for j in i('span', {'class': 'company'}):
#             print 'Comapany name is %s' % j.text 
#             salary_80k.append(j.text)
#         for j in i('span', {'class': 'location'}):
#             print 'Job is located in %s' % j.text
#             salary_80k.append(j.text)
#         for j in i('span', {'class': 'summary'}):
#             print 'Job summary is %s' % j.text
#             salary_80k.append(j.text)
            
# redo above code using this as template            
job_title = []
company_name = []
location = []
summary = []
for i in range(0,501,10):
    time.sleep(1)
    print 'starting loop', i
    web_page = 'http://www.indeed.com/jobs?q=data+scientist+$80,000&l=Chicago,+IL&start=' + str(i)
    print web_page
    soup80 = BeautifulSoup(urllib2.urlopen(web_page).read())
    for i in soup80('div', {'class': ' row result'}):
        for j in i('a', {'data-tn-element': 'jobTitle'}):
            print 'Job title is %s' % j.text
            job_title.append((j.text).encode('utf-8').strip())
        for j in i('span', {'class': 'company'}):
            print 'Comapany name is %s' % j.text 
            company_name.append((j.text).encode('utf-8').strip())
        for j in i('span', {'class': 'location'}):
            print 'Job is located in %s' % j.text
            location.append((j.text).encode('utf-8').strip())
        for j in i('span', {'class': 'summary'}):
            print 'Job summary is %s' % j.text
            summary.append((j.text).encode('utf-8').strip())
# Out:
# starting loop 0
# http://www.indeed.com/jobs?q=data+scientist+$80,000&l=Chicago,+IL&start=0
# Job title is Data Scientist
# Comapany name is
#
#     Strike Social
#
# Job is located in Chicago, IL 60601 (Loop area)
# Job summary is
# Data Scientist at Strike Social. Our Data Scientists research and create our learning infrastructure using R and Python and then work with Data Engineering to...
# Job title is AVP, Credit Innovation Data Scientist (L11)
# Comapany name is
#
#
#         Synchrony Financial
#
# Job is located in Chicago, IL
# Job summary is
# We are looking for scientists who are curious and passionate about mining data and have experience in statistical programming, SAS, machine learning, and use of...
# Job title is Data Scientist
# Comapany name is
#
#     Inficare
#
# Job is located in Chicago, IL
# Job summary is
# ...

# %%
# added salary column here
salary_80k = {'Job Title' : job_title, 'Company Name' : company_name, 
               'Location' : location, 'Summary' : summary, 'Salary' : 80000,
              'High Salary' : 0}
salary_80k
# Out:
# {'Company Name': ['Digital Factory',
#   'Anomalix',
#   'GE Transportation',
#   'Google',
#   'Civis Analytics',
#   'Illinois Technology Association',
#   'Civis Analytics',
#   'BMW Technology Corporation',
#   'Wolverine Trading',
#   'IBM',
#   'Willis Towers Watson',
#   'VitalSource Staffing',
#   'Hirewell',
#   'Enterprise Consulting Services',
#   'Selby Jennings',
#   'University of Chicago, Center for Data Intensive S',
#   'Trunk Club',
#   'Workbridge Associates',
#   'Civis Analytics',
#   'NJF Search',
#   'Allstate Insurance',
#   'Analytic Recruiting',
#   'e.biT',
#   'Civis Analytics',
#   'Civis Analytics',
#   'Optiver',
#   'Civis Analytics',
#   'Johnson Controls',
#   'Deloitte',
#   'GinasTechJobs.com',
#   'Shoprunner',
#   'Hirewell',
#   'Workbridge Associates',
#   'Civis Analytics',
#   'Amazon Web Services, Inc.',
#   'Raise Marketplace Inc.',
#   'Metropolitan Water Reclamation District of Greater...',
#   'IBM Kenexa',
#   'Capgemini',
# ...

# %%
df_80 = pd.DataFrame(salary_80k)
df_80.head()
# Out:
#         Company Name  High Salary  \
# 0    Digital Factory            0
# 1           Anomalix            0
# 2  GE Transportation            0
# 3             Google            0
# 4    Civis Analytics            0
#
#                                            Job Title     Location  Salary  \
# 0             Chief Data Scientist (equity position)  Chicago, IL   80000
# 1                                     Data Scientist  Chicago, IL   80000
# 2                              Senior Data Scientist  Chicago, IL   80000
# 3  Machine Learning Deployment Engineer, Professi...  Chicago, IL   80000
# 4                 Data Scientist - Unstructured Data  Chicago, IL   80000
#
#                                              Summary
# 0  Chief Data Scientist*. We are looking for an e...
# 1  Data Scientist Responsibilities will include:....
# 2  The Senior Data Scientist will demonstrate lea...
# 3  Experience interpreting technical data and cre...
# ...

# %% [markdown]
# MOVING ON TO $105,000

# %%
http://www.indeed.com/jobs?q=data+scientist+$105,000&l=Chicago,+IL&start=

# %%
# salary_105k = []
# for i in range(0,501,10):
#     time.sleep(1)
#     print 'starting loop', i
#     web_page = 'http://www.indeed.com/jobs?q=data+scientist+$105,000&l=Chicago,+IL&start=' + str(i)
#     print web_page
#     soup105 = BeautifulSoup(urllib2.urlopen(web_page).read())
#     for i in soup105('div', {'class': ' row result'}):
#         for j in i('span', {'class': 'company'}):
#             print 'Comapany name is %s' % j.text 
#             salary_105k.append(j.text)
#         for j in i('span', {'class': 'location'}):
#             print 'Job is located in %s' % j.text
#             salary_105k.append(j.text)
#         for j in i('span', {'class': 'summary'}):
#             print 'Job summary is %s' % j.text
#             salary_105k.append(j.text)

# redo above code using this as template            
job_title = []
company_name = []
location = []
summary = []
for i in range(0,501,10):
    time.sleep(1)
    print 'starting loop', i
    web_page = 'http://www.indeed.com/jobs?q=data+scientist+$105,000&l=Chicago,+IL&start=' + str(i)
    print web_page
    soup105 = BeautifulSoup(urllib2.urlopen(web_page).read())
    for i in soup105('div', {'class': ' row result'}):
        for j in i('a', {'data-tn-element': 'jobTitle'}):
            print 'Job title is %s' % j.text
            job_title.append((j.text).encode('utf-8').strip())
        for j in i('span', {'class': 'company'}):
            print 'Comapany name is %s' % j.text 
            company_name.append((j.text).encode('utf-8').strip())
        for j in i('span', {'class': 'location'}):
            print 'Job is located in %s' % j.text
            location.append((j.text).encode('utf-8').strip())
        for j in i('span', {'class': 'summary'}):
            print 'Job summary is %s' % j.text
            summary.append((j.text).encode('utf-8').strip())
# Out:
# starting loop 0
# http://www.indeed.com/jobs?q=data+scientist+$105,000&l=Chicago,+IL&start=0
# Job title is Data Scientist
# Comapany name is
#
#     Strike Social
#
# Job is located in Chicago, IL 60601 (Loop area)
# Job summary is
# Data Scientist at Strike Social. Our Data Scientists research and create our learning infrastructure using R and Python and then work with Data Engineering to...
# Job title is Data Scientist
# Comapany name is
#
#
#         Third Eye
#
# Job is located in Chicago, IL 60601 (Loop area)
# Job summary is
# Be a key component of the Big Data and Data Sciences CoE, working directly with clients to solve varied business issues using internal and external data....
# Job title is Data Scientist
# Comapany name is
#
#
#         KPMG
#
# Job is located in Chicago, IL 60601 (Loop area)
# Job summary is
# ...

# %%
# added salary column here
salary_105k = {'Job Title' : job_title, 'Company Name' : company_name, 
               'Location' : location, 'Summary' : summary, 'Salary' : 105000,
               'High Salary' : 1}
salary_105k
# Out:
# {'Company Name': ['Digital Factory',
#   'Anomalix',
#   'GE Transportation',
#   'Google',
#   'Civis Analytics',
#   'Illinois Technology Association',
#   'Civis Analytics',
#   'BMW Technology Corporation',
#   'Wolverine Trading',
#   'IBM',
#   'Willis Towers Watson',
#   'VitalSource Staffing',
#   'Hirewell',
#   'Enterprise Consulting Services',
#   'Selby Jennings',
#   'University of Chicago, Center for Data Intensive S',
#   'Trunk Club',
#   'Workbridge Associates',
#   'Civis Analytics',
#   'NJF Search',
#   'Allstate Insurance',
#   'Analytic Recruiting',
#   'e.biT',
#   'Civis Analytics',
#   'Civis Analytics',
#   'Optiver',
#   'Civis Analytics',
#   'Johnson Controls',
#   'Deloitte',
#   'GinasTechJobs.com',
#   'Shoprunner',
#   'Hirewell',
#   'Workbridge Associates',
#   'Civis Analytics',
#   'Amazon Web Services, Inc.',
#   'Raise Marketplace Inc.',
#   'Metropolitan Water Reclamation District of Greater...',
#   'IBM Kenexa',
#   'Capgemini',
# ...

# %%
df_105 = pd.DataFrame(salary_105k)
df_105.head()
# Out:
#         Company Name  High Salary  \
# 0    Digital Factory            1
# 1           Anomalix            1
# 2  GE Transportation            1
# 3             Google            1
# 4    Civis Analytics            1
#
#                                            Job Title     Location  Salary  \
# 0             Chief Data Scientist (equity position)  Chicago, IL  105000
# 1                                     Data Scientist  Chicago, IL  105000
# 2                              Senior Data Scientist  Chicago, IL  105000
# 3  Machine Learning Deployment Engineer, Professi...  Chicago, IL  105000
# 4                 Data Scientist - Unstructured Data  Chicago, IL  105000
#
#                                              Summary
# 0  Chief Data Scientist*. We are looking for an e...
# 1  Data Scientist Responsibilities will include:....
# 2  The Senior Data Scientist will demonstrate lea...
# 3  Experience interpreting technical data and cre...
# ...

# %%
len(salary_105k)
# Out:
# 297

# %% [markdown]
# MOVING ON TO $120,000

# %%
http://www.indeed.com/jobs?q=data+scientist+%24120%2C000&l=Chicago%2C+IL&start=

# %%
# ran it and its working right now
# added unicode strip, hopefully everything in my list should become a string...
job_title = []
company_name = []
location = []
summary = []
# salary_120k = []
# run range(0,501,10)
for i in range(0,501,10):
    time.sleep(1)
    print 'starting loop', i
    web_page = 'http://www.indeed.com/jobs?q=data+scientist+$120,000&l=Chicago,+IL&start=' + str(i)
    print web_page
    soup120 = BeautifulSoup(urllib2.urlopen(web_page).read())
    for i in soup120('div', {'class': ' row result'}):
        for j in i('a', {'data-tn-element': 'jobTitle'}):
            print 'Job title is %s' % j.text
            job_title.append((j.text).encode('utf-8').strip())
        for j in i('span', {'class': 'company'}):
            print 'Comapany name is %s' % j.text 
            company_name.append((j.text).encode('utf-8').strip())
        for j in i('span', {'class': 'location'}):
            print 'Job is located in %s' % j.text
            location.append((j.text).encode('utf-8').strip())
        for j in i('span', {'class': 'summary'}):
            print 'Job summary is %s' % j.text
            # add .strip() to everything
            summary.append((j.text).encode('utf-8').strip())
# Out:
# starting loop 0
# http://www.indeed.com/jobs?q=data+scientist+$120,000&l=Chicago,+IL&start=0
# Job title is Chief Data Scientist (equity position)
# Comapany name is
#
#     Digital Factory
#
# Job is located in Chicago, IL
# Job summary is
# Chief Data Scientist*. We are looking for an experienced Data Scientist that will work with the Research/Development teams to provide insights into mobile data...
# Job title is Data Scientist
# Comapany name is
#
#     Anomalix
#
# Job is located in Chicago, IL
# Job summary is
# Data Scientist Responsibilities will include:. Anomalix is looking for strong data scientist candidates to join a team building out our flagship enterprise...
# Job title is Senior Data Scientist
# Comapany name is
#
#
#         GE Transportation
#
# Job is located in Chicago, IL
# Job summary is
# The Senior Data Scientist will demonstrate leadership in communicating business goals, programs, and processes for multiple areas or business / market segments....
# ...

# %%
print company_name
# Out:
# ['\n\n    Digital Factory\n', '\n\n\n        GE Transportation\n', '\n\n    Illinois Technology Association\n', '\n\n\n        Capital One\n', '\n\n    Illinois Technology Association\n', '\n\n    Civis Analytics\n', '\n\n    Wolverine Trading\n', '\n\n\n        Google\n', '\n\n\n        Willis Towers Watson\n', '\n\n    e.biT\n', '\n\n    BMW Technology Corporation\n', '\n\n\n        Enterprise Consulting Services\n', '\n\n    Hirewell\n', '\n\n    University of Chicago, Center for Data Intensive S\n', '\n\n    Civis Analytics\n', '\n\n\n        Allstate Insurance\n', '\n\n    GinasTechJobs.com\n', '\n\n\n        Amazon Web Services, Inc.\n', '\n\n\n        JPMorgan Chase\n', '\n\n\n        Johnson Controls\n', '\n\n    Civis Analytics\n', '\n\n    Civis Analytics\n', '\n\n    Illinois Technology Association\n', '\n\n    Anomalix\n', '\n\n\n        Trunk Club\n', '\n\n\n        Optiver\n', '\n\n    Selby Jennings\n', '\n\n    Shoprunner\n', '\n\n    NJF Search\n', '\n\n\n        HER
# ...

# %%
print job_title
# Out:
# ['Chief Data Scientist (equity position)', 'Senior Data Scientist', 'Data Scientist', 'Data Scientist - Unstructured Data', 'Machine Learning Deployment Engineer, Professional Services,...', 'Principal Data Scientist - 16-00217', 'Senior Data Scientist - Unstructured Data', 'Software Engineer-Data and Algorithms', 'Machine Learning Data Scientist', 'Data Quality Engineer', 'Supervising Environmental Soil Scientist', 'Data Analytics Manager', 'Advanced Analytics Enablement Big Data Senior Consultant', 'Director of Data Science', 'Data Scientist - Multiple Roles Available', 'New Graduate - Applied Data Scientist', 'Data Scientist', 'Data Scientists and Quantitative Researchers', 'Data Scientist -Fitness/Wellness Firm', 'Data Scientist - Engineering', 'Senior Data Scientist - HERE Maps Chicago', 'Data Scientist - Statistics', 'Data Scientist \xe2\x80\x93 Big Data/Artificial Intelligence', 'Data Scientist - High Frequency Trading', 'Lead Data Engineer', 'Applied Data Science Manager', 'L
# ...

# %%
# added salary column here
salary_120k = {'Job Title' : job_title, 'Company Name' : company_name, 
               'Location' : location, 'Summary' : summary, 'Salary' : 120000,
               'High Salary' : 1}
salary_120k
# Out:
# {'Company Name': ['Digital Factory',
#   'Anomalix',
#   'GE Transportation',
#   'Google',
#   'Civis Analytics',
#   'Illinois Technology Association',
#   'Civis Analytics',
#   'BMW Technology Corporation',
#   'Wolverine Trading',
#   'IBM',
#   'Willis Towers Watson',
#   'VitalSource Staffing',
#   'Hirewell',
#   'Enterprise Consulting Services',
#   'Selby Jennings',
#   'University of Chicago, Center for Data Intensive S',
#   'Trunk Club',
#   'Workbridge Associates',
#   'Civis Analytics',
#   'NJF Search',
#   'Allstate Insurance',
#   'Analytic Recruiting',
#   'e.biT',
#   'Civis Analytics',
#   'Civis Analytics',
#   'Optiver',
#   'Civis Analytics',
#   'Johnson Controls',
#   'Deloitte',
#   'GinasTechJobs.com',
#   'Shoprunner',
#   'Hirewell',
#   'Workbridge Associates',
#   'Civis Analytics',
#   'Amazon Web Services, Inc.',
#   'Raise Marketplace Inc.',
#   'Metropolitan Water Reclamation District of Greater...',
#   'IBM Kenexa',
#   'Capgemini',
# ...

# %%
import pandas as pd

# %%
df_120 = pd.DataFrame(salary_120k)

# %%
df_120.head()
# Out:
#         Company Name  High Salary  \
# 0    Digital Factory            1
# 1           Anomalix            1
# 2  GE Transportation            1
# 3             Google            1
# 4    Civis Analytics            1
#
#                                            Job Title     Location  Salary  \
# 0             Chief Data Scientist (equity position)  Chicago, IL  120000
# 1                                     Data Scientist  Chicago, IL  120000
# 2                              Senior Data Scientist  Chicago, IL  120000
# 3  Machine Learning Deployment Engineer, Professi...  Chicago, IL  120000
# 4                 Data Scientist - Unstructured Data  Chicago, IL  120000
#
#                                              Summary
# 0  Chief Data Scientist*. We are looking for an e...
# 1  Data Scientist Responsibilities will include:....
# 2  The Senior Data Scientist will demonstrate lea...
# 3  Experience interpreting technical data and cre...
# ...

# %% [markdown]
# This is exciting! I made something work! Just need to strip out that pesky unicode

# %%
# now that I have all my dataframes made I need to concat them all together

# %%
# here are all my df's I want to concat
# do I want to use zip, join, merge, or concat?
df_55
df_70
df_80
df_105
df_120
df_120.head()
# Out:
#         Company Name  High Salary  \
# 0    Digital Factory            1
# 1           Anomalix            1
# 2  GE Transportation            1
# 3             Google            1
# 4    Civis Analytics            1
#
#                                            Job Title     Location  Salary  \
# 0             Chief Data Scientist (equity position)  Chicago, IL  120000
# 1                                     Data Scientist  Chicago, IL  120000
# 2                              Senior Data Scientist  Chicago, IL  120000
# 3  Machine Learning Deployment Engineer, Professi...  Chicago, IL  120000
# 4                 Data Scientist - Unstructured Data  Chicago, IL  120000
#
#                                              Summary
# 0  Chief Data Scientist*. We are looking for an e...
# 1  Data Scientist Responsibilities will include:....
# 2  The Senior Data Scientist will demonstrate lea...
# 3  Experience interpreting technical data and cre...
# ...

# %%
frames = [df_55, df_70, df_80, df_105, df_120]
result = pd.concat(frames)

# %%
job_data = pd.DataFrame(result)
job_data
# Out:
#                                           Company Name  High Salary  \
# 0                                      Digital Factory            0
# 1                                             Anomalix            0
# 2                                    GE Transportation            0
# 3                                               Google            0
# 4                                      Civis Analytics            0
# 5                      Illinois Technology Association            0
# 6                                      Civis Analytics            0
# 7                           BMW Technology Corporation            0
# 8                                    Wolverine Trading            0
# 9                                                  IBM            0
# 10                                Willis Towers Watson            0
# 11                                VitalSource Staffing            0
# 12                                            Hirewell            0
# ...

# %% [markdown]
# The describe below shows the median income from all my job listings to be roughly $82,000. Based on the average salary for Chicago job listings I am going to determine my high_salary column to be limited to salaries greater than or equal to $105,000.

# %%
# will return to above dicts and add high_salary column and 1 or 0 based on above assumptions.
job_data['Salary'].describe()
# Out:
# count      1462.000000
# mean      82332.421341
# std       24663.324272
# min       55000.000000
# 25%       55000.000000
# 50%       80000.000000
# 75%      105000.000000
# max      120000.000000
# Name: Salary, dtype: float64

# %%
# shows that 660 job listings qualify as 'high salary'
job_data['High Salary'].value_counts()
# Out:
# 0    990
# 1    660
# Name: High Salary, dtype: int64

# %%
# need to turn job_data into a csv file

# %%
import os
# %pwd
# Out:
# u'/Users/Driz/DSI-CHI-1'

# %%
# to csv
job_data.to_csv('../data_sets/job_data.csv', encoding='utf-8')

# %%
# job_data['Company Name'].str.strip()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2d8cf07c8adc> in <module>()
# ----> 1 job_data['Company Name'].str.strip()
#
# NameError: name 'job_data' is not defined

# %%
# didnt work correctly
# here i am adding the salary to the job listing row
salary_120k
for i in range(len(salary_120k)):
    salary_120k[i].append(int(120000))
print salary_120k
# Out:
# [[120000]]

# %%
# this didnt work, went back up and made each variable its own list then combined into a df
# test to put a list in a list
salary_120k = []
for i in range(0,101,10):
    time.sleep(1)
    print 'starting loop', i
    web_page = 'http://www.indeed.com/jobs?q=data+scientist+$120,000&l=Chicago,+IL&start=' + str(i)
    print web_page
    soup120 = BeautifulSoup(urllib2.urlopen(web_page).read())
    salary_120k.append([])
    for i in soup120('div', {'class': ' row result'}):
        for j in i('span', {'class': 'company'}):
            print 'Comapany name is %s' % j.text 
            salary_120k[i].append((j.text).encode('utf-8'))
        for j in i('span', {'class': 'location'}):
            print 'Job is located in %s' % j.text
            salary_120k[i].append((j.text).encode('utf-8'))
        for j in i('span', {'class': 'summary'}):
            print 'Job summary is %s' % j.text
            salary_120k[i].append((j.text).encode('utf-8'))
            salary_120k.append(int(120000))
# Out:
# starting loop 0
# http://www.indeed.com/jobs?q=data+scientist+$120,000&l=Chicago,+IL&start=0
# Comapany name is
#
#     Digital Factory
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-f7b349c097ca> in <module>()
#      11         for j in i('span', {'class': 'company'}):
#      12             print 'Comapany name is %s' % j.text
# ---> 13             salary_120k[i].append((j.text).encode('utf-8'))
#      14         for j in i('span', {'class': 'location'}):
#      15             print 'Job is located in %s' % j.text
#
# TypeError: list indices must be integers, not Tag

# %%
type(salary_120k[0])
# Out:
# unicode

# %% [markdown]
# I went back up and fixed this issue
#
# I think I figured out why I keep getting the same job results. My for loop says for i in soup.
# I need to define my for loop that goes through the filtered salary pages.

# %%
#here I want to pull all my descriptive info from each page through looping
# job_title = []
# company_name = []
# location = []
# rating = []
# description = []

# gData = soup.find_all("div",{"class":"row result"})
# for item in gData:
#     job_title.append(item.find_all("a",{"data-tn-element":"jobTitle"})[0].text)
#     company_name = item.find_all("span",{"class":"company"})
#     location=item.find_all("span",{"class":"location"})
#     rating=item.find_all("span",{"class":"rating"})
#     description=item.find_all("span",{"class":"summary"})
   
# gData = soup.find_all("div",{"class":" row result"})
# for item in gData:
#     job_title.append(item.find_all("a",{"data-tn-element":"jobTitle"})[0].text)
#     company_name = item.find_all("span",{"class":"company"})
#     location=item.find_all("span",{"class":"location"})
#     rating=item.find_all("span",{"class":"rating"})
#     description=item.find_all("span",{"class":"summary"})

# for i in range(0, len(job_title)):
#     print job_title[i]
#     print company_name[i]
#     print location[i]
#     print rating[i]
#     print description[i]

# %% [markdown]
# After looping through all my pages and pulling info for each salary range into a list, I then want to concat all the salary lists and make one table.
# (http://pandas.pydata.org/pandas-docs/stable/merging.html)
